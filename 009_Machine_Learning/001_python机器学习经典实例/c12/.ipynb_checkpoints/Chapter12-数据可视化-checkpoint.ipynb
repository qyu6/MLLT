# %% [markdown]
# Agenda
# - 3D散点图
# - 气泡图
# - 动态气泡图
# - 饼图
# - 日期格式时间序列图
# - 直方图
# - 可视化热力图
# - 动态信号的可视化模拟

# %%
# 3D动态散点图
# %run scatter_3d.py

# %%
# 画气泡图
# %run bubble_plot.py

# %%
# 动态气泡图
# %run dynamic_bubble_plot.py
# Out:
# C:\Users\Tony\Downloads\Github-MLLT\MLLT\009_Machine_Learning\001_python机器学习经典实例\c12\dynamic_bubble_plot.py:36: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   datapoints = np.zeros(num_points, dtype=[('position', float, 2),

# %%
# 饼图
# %run pie_chart.py

# %%
# 画日期格式的时间序列数据 - matplotlib预置数据集丢失，无法实验
# %run time_series.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Downloads\Github-MLLT\MLLT\009_Machine_Learning\001_python机器学习经典实例\c12\time_series.py:33, in <module>
#      30 input_file = cbook.get_sample_data('aapl.csv', asfileobj=False)
#      32 # Load csv file into numpy record array
# ---> 33 data = csv2rec(input_file)
#      35 # Take a subset for plotting
#      36 data = data[-70:]
#
# File ~\Downloads\Github-MLLT\MLLT\009_Machine_Learning\001_python机器学习经典实例\c12\time_series.py:13, in csv2rec(filename)
#      12 def csv2rec(filename):
# ---> 13     return np.recfromtxt(filename, dtype=None, delimiter=',', names=True, encoding='utf-8')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:2454, in recfromtxt(fname, **kwargs)
#    2452 kwargs.setdefault("dtype", None)
#    2453 usemask = kwargs.get('usemask', False)
# ...

# %%
# 直方图
# %run histogram.py

# %%
# 可视化热力图
# %run heatmap.py

# %%
# 动态数据信号的可视化模拟
# %run moving_wave_variable.py
